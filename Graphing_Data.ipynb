# %% [markdown]
# ## Graphing Final Results

# %%
rp = [0.4689810606060606, 0.6855946969696969, 0.8547765151515151, 0.9181893939393939, 0.935465909090909]
ts = [0.5050075757575757, 0.7815037878787878, 0.8513484848484849, 0.9314886363636363, 0.9500113636363636]
cpc = [0.5484583333333334, 0.6462386363636364, 0.6729166666666668, 0.8481856060606059, 0.8696249999999999]

ramdom_weights = [0.3471666666666667, 0.34206060606060606, 0.3911098484848485, 0.5020492424242424, 0.5661893939393939]
full_sup = [0.41169696969696973, 0.4972234848484849, 0.6805530303030303, 0.854409090909091, 0.9312083333333334]
All3_combined = [0.6547992424242424, 0.8585719696969697, 0.9048257575757577, 0.938746212121212, 0.9544659090909091]

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

plt.figure(num=None, figsize=(10, 10))

xvals = [1, 10, 100, 1000, 3000] #the 2000 is kinda bs, fix this
plt.semilogx(xvals, rp, 'b.-', label="RP", markersize=14)
plt.semilogx(xvals, ts, 'yx-', label="TS", markersize=14)
plt.semilogx(xvals, cpc, 'g*-', label="CPC", markersize=14)
plt.semilogx(xvals, ramdom_weights, 'm+-', label="Random", markersize=14)
plt.semilogx(xvals, full_sup, 'r.-', label="Full Super.", markersize=14)

plt.legend()
plt.xlabel("Number of Examples Per Class", fontsize=18)
plt.ylabel("Test Set Accuracy", fontsize=18)
plt.show()

# %% [markdown]
# ## After Adding More Data

# %%
rp_and_ts = [0.5580871212121212, 0.8284545454545456, 0.8890378787878788, 0.9424356060606061, 0.9550568181818182]
ts_and_cpc = [0.6103068181818182, 0.8269090909090909, 0.8815113636363636, 0.9322386363636364, 0.9517613636363637]
rp_and_cpc = [0.6458068181818182, 0.8400265151515152, 0.8980492424242424, 0.921814393939394, 0.9393863636363635]

# %%
# %matplotlib inline

plt.figure(num=None, figsize=(10, 10))

xvals = [1, 10, 100, 1000, 3000] #the 2000 is kinda bs, fix this
plt.semilogx(xvals, rp_and_ts, 'b.-', label="RP+TS", markersize=14)
plt.semilogx(xvals, ts_and_cpc, 'yx-', label="TS+CPC", markersize=14)
plt.semilogx(xvals, rp_and_cpc, 'g*-', label="RP+CPC", markersize=14)
plt.semilogx(xvals, All3_combined, '*-', label="All 3", markersize=14)

plt.legend()
plt.xlabel("Number of Examples Per Class", fontsize=18)
plt.ylabel("Test Set Accuracy", fontsize=18)
plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt


plt.figure(num=None, figsize=(20, 10))

plt.subplot(1,3,1)
xvals = [1, 10, 100, 1000, 3000] #the 2000 is kinda bs, fix this
plt.semilogx(xvals, rp, 'b.-', label="RP", markersize=14)
plt.semilogx(xvals, ts, 'yx-', label="TS", markersize=14)
plt.semilogx(xvals, rp_and_ts, 'm+-', label="RP+TS", markersize=14)

plt.legend()
plt.xlabel("Number of Examples Per Class", fontsize=18)
plt.ylabel("Test Set Accuracy", fontsize=18)

plt.subplot(1,3,2)
xvals = [1, 10, 100, 1000, 3000] #the 2000 is kinda bs, fix this
plt.semilogx(xvals, rp, 'b.-', label="RP", markersize=14)
plt.semilogx(xvals, cpc, 'g*-', label="CPC", markersize=14)
plt.semilogx(xvals, rp_and_cpc, 'm+-', label="RP+CPC", markersize=14)

plt.legend()
plt.xlabel("Number of Examples Per Class", fontsize=18)
plt.ylabel("Test Set Accuracy", fontsize=18)

plt.subplot(1,3,3)
xvals = [1, 10, 100, 1000, 3000] #the 2000 is kinda bs, fix this
plt.semilogx(xvals, cpc, 'g*-', label="CPC", markersize=14)
plt.semilogx(xvals, ts, 'yx-', label="TS", markersize=14)
plt.semilogx(xvals, ts_and_cpc, 'm+-', label="TS+CPC", markersize=14)

plt.legend()
plt.xlabel("Number of Examples Per Class", fontsize=18)
plt.ylabel("Test Set Accuracy", fontsize=18)
plt.show()

# %% [markdown]
# # Multiple losses
#
# ### Caveat Here is only trained 2 of the 5 leave one outs

# %%
import numpy as np
vals = {1: [0.7989583333333333, 0.8965909090909091], 10: [0.91375, 0.9054545454545454], 100: [0.9329166666666666, 0.9275], 1000: [0.9333333333333333, 0.9259090909090909], None: [0.9470833333333334, 0.9363636363636364]}
multi_loss = [np.mean(vals[key]) for key in vals]

# %%
plt.figure(num=None, figsize=(10, 10))

xvals = [1, 10, 100, 1000, 3000] #the 2000 is kinda bs, fix this
plt.semilogx(xvals, rp, 'b.-', label="RP", markersize=14)
plt.semilogx(xvals, All3_combined, 'yx-', label="All 3", markersize=14)
plt.semilogx(xvals, multi_loss, 'g*-', label="Multi Loss", markersize=14)
plt.semilogx(xvals, full_sup, 'r.-', label="Full Super.", markersize=14)

plt.legend()
plt.xlabel("Number of Examples Per Class", fontsize=18)
plt.ylabel("Test Set Accuracy", fontsize=18)
plt.show()
