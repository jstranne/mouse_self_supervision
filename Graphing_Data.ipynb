# %% [markdown]
# ## Graphing Final Results

# %%
rp = [0.5716055555555556, 0.7413722222222111, 0.8536277777777777, 0.8988888888888887, 0.9076166666666666]
ts = [0.5332666666666667, 0.7857222222222222, 0.872661111111111, 0.9334055555555555, 0.9409222222222221]
cpc = [0.5034555555555555, 0.6471388888888888, 0.7719722222222223, 0.8523888888888888, 0.8694777777777779]


ramdom_weights = [0.35394444444444445, 0.34443333333333337, 0.35025, 0.5068611111111111, 0.5478166666666665]
full_sup = [0.3358833333333333, 0.35051111111111116, 0.37330555555555556, 0.849538888888889, 0.8944111111111112]
All3_combined = [0.6305499999999999, 0.8377333333333333, 0.8911222222222221, 0.9293666666666667, 0.9474888888888889]

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

plt.figure(num=None, figsize=(10, 10))

xvals = [1, 10, 100, 1000, 3000] #the 2000 is kinda bs, fix this
plt.semilogx(xvals, rp, 'b.-', label="RP", markersize=14)
plt.semilogx(xvals, ts, 'yx-', label="TS", markersize=14)
plt.semilogx(xvals, cpc, 'g*-', label="CPC", markersize=14)
plt.semilogx(xvals, ramdom_weights, 'm+-', label="Random", markersize=14)
plt.semilogx(xvals, full_sup, 'r.-', label="Full Supervision", markersize=14)

plt.legend(fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Number of Examples Per Class", fontsize=22)
plt.ylabel("Test Set Accuracy", fontsize=22)
plt.savefig('basic_results.png')
plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

plt.figure(num=None, figsize=(10, 10))

xvals = [1, 10, 100, 1000, 3000] #the 2000 is kinda bs, fix this
plt.semilogx(xvals, rp, 'b.-', label="RP", markersize=14)
plt.semilogx(xvals, ts, 'yx-', label="TS", markersize=14)
plt.semilogx(xvals, cpc, 'g*-', label="CPC", markersize=14)
plt.semilogx(xvals, All3_combined, 'm+-', label="All Pretext Tasks", markersize=14)

plt.legend(fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.xlabel("Number of Examples Per Class", fontsize=22)
plt.ylabel("Test Set Accuracy", fontsize=2)
plt.savefig('all3vssingle.png')
plt.show()

# %% [markdown]
# ## After Adding More Data

# %%
rp_and_ts = [0.5774555555555555, 0.8220055555555555, 0.8892833333333332, 0.9307666666666666, 0.9458222222222222]
ts_and_cpc = [0.5681777777777778, 0.8262777777777778, 0.8890944444444445, 0.9323, 0.9443888888888888]
rp_and_cpc = [0.5672333333333333, 0.816661111111111, 0.8666888888888886, 0.900588888888889, 0.9170777777777778]

# %%
# %matplotlib inline

plt.figure(num=None, figsize=(10, 10))

xvals = [1, 10, 100, 1000, 3000] #the 2000 is kinda bs, fix this
plt.semilogx(xvals, rp_and_ts, 'b.-', label="RP+TS", markersize=14)
plt.semilogx(xvals, ts_and_cpc, 'yx-', label="TS+CPC", markersize=14)
plt.semilogx(xvals, rp_and_cpc, 'g*-', label="RP+CPC", markersize=14)
plt.semilogx(xvals, All3_combined, '*-', label="All 3", markersize=14)

plt.legend(fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Number of Examples Per Class", fontsize=22)
plt.ylabel("Test Set Accuracy", fontsize=22)
plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt


plt.figure(num=None, figsize=(20, 10))

plt.subplot(1,3,1)
xvals = [1, 10, 100, 1000, 3000] 
plt.semilogx(xvals, rp, 'b.-', label="RP", markersize=14)
plt.semilogx(xvals, ts, 'yx-', label="TS", markersize=14)
plt.semilogx(xvals, rp_and_ts, 'm+-', label="RP+TS", markersize=14)

plt.legend(fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Number of Examples Per Class", fontsize=22)
plt.ylabel("Test Set Accuracy", fontsize=22)

plt.subplot(1,3,2)
xvals = [1, 10, 100, 1000, 3000] 
plt.semilogx(xvals, rp, 'b.-', label="RP", markersize=14)
plt.semilogx(xvals, cpc, 'g*-', label="CPC", markersize=14)
plt.semilogx(xvals, rp_and_cpc, 'm+-', label="RP+CPC", markersize=14)

plt.legend(fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Number of Examples Per Class", fontsize=22)
plt.ylabel("Test Set Accuracy", fontsize=22)

plt.subplot(1,3,3)
xvals = [1, 10, 100, 1000, 3000] 
plt.semilogx(xvals, cpc, 'g*-', label="CPC", markersize=14)
plt.semilogx(xvals, ts, 'yx-', label="TS", markersize=14)
plt.semilogx(xvals, ts_and_cpc, 'm+-', label="TS+CPC", markersize=14)

plt.legend(fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Number of Examples Per Class", fontsize=22)
plt.ylabel("Test Set Accuracy", fontsize=22)
plt.savefig('twovsone.png')

plt.show()

# %% [markdown]
# # Multiple losses
#
# ### Caveat Here is only trained 2 of the 5 leave one outs

# %%
import numpy as np
vals = {1: [0.7989583333333333, 0.8965909090909091], 10: [0.91375, 0.9054545454545454], 100: [0.9329166666666666, 0.9275], 1000: [0.9333333333333333, 0.9259090909090909], None: [0.9470833333333334, 0.9363636363636364]}
multi_loss = [np.mean(vals[key]) for key in vals]

# %%
plt.figure(num=None, figsize=(10, 10))

xvals = [1, 10, 100, 1000, 3000] #the 2000 is kinda bs, fix this
plt.semilogx(xvals, rp, 'b.-', label="RP", markersize=14)
plt.semilogx(xvals, All3_combined, 'yx-', label="All 3", markersize=14)
plt.semilogx(xvals, multi_loss, 'g*-', label="Multi Loss", markersize=14)
plt.semilogx(xvals, full_sup, 'r.-', label="Full Super.", markersize=14)

plt.legend(fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Number of Examples Per Class", fontsize=22)
plt.ylabel("Test Set Accuracy", fontsize=22)
plt.show()
